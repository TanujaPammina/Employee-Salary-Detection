# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
data = pd.read_csv(r"C:\Users\tanuja\Downloads\archive (3)\salary_data.csv")
print(data.head())
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
#Scatter plot between years experience and salary
data.plot.scatter('YearsExperience','Salary')
# Out:
# <Axes: xlabel='YearsExperience', ylabel='Salary'>

# %%
#Split data
x = data[['YearsExperience']]
y = data['Salary']
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2, random_state = 42)

# %%
model = LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
import pandas as pd

years_exp = 5
input_df = pd.DataFrame([[years_exp]], columns=['YearsExperience'])  # match training feature name
predicted_salary_float = model.predict(input_df)[0]
predicted_salary_int = int(round(predicted_salary_float))

print("Predicted Salary:", predicted_salary_int)
# Out:
# Predicted Salary: 72068

# %%
print("R^2 Score:",r2_score(y_test,y_pred))
# Out:
# R^2 Score: 0.9303200001274765

# %%
exact_salary = data.loc[(data['Salary']-predicted_salary_int).abs().idxmin(),'Salary']
print("Exact Salary: ",exact_salary)
# Out:
# Exact Salary:  67938.0
